# %%
from surface_code_ideal import surface_code_sim

# %%
display_mode = True

# %%
p = 0.155
d = 5
error_mode = 'depolarizing'
s = surface_code_sim(d, p, error_mode, display_mode)

# %% [markdown]
# ### The green nodes are z measurement nodes. An edge is present between them if that qubit has a bit flip error. The bit flip probability is p under 'uncorrelated error mode' and 2*p/3 under 'depolarizing.' The blue nodes are boundary nodes. They are present to allow for bit flips on the boundary, and cannot have edges between them. ###

# %%
s.simulate_step()
print('Failure: ', s.logical_error)
# Out:
# (1) pre_corrections
# (2) post_corrections
# Failure:  False
